# %%
import stability_functions as sf
import numpy as np
from numpy.random import normal, seed, uniform
import os
import time
import sys
import rebound
import mr_forecast as mr
import numpy.random as rd
import radvel
import corner
import copy
import scipy
import pandas as pd
from scipy import optimize
from radvel.plot import orbit_plots
# plotting
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
seconds_p_day = 86400
days_p_year = 365.25
meters_p_AU = 149597870700
earth_mass_2_solar_mass = 0.000003003
year_p_reboundtime = 1 / (2 * np.pi)

# %%
if sys.argv[1] != "-f":
    err_ind = int(sys.argv[1])
else:
#     err_ind = -1
    err_ind = 0
df = pd.read_pickle("mcmc/mcmc_%d.pkl"%err_ind)
df = df.drop(columns="jit")
df = df.drop(columns="lnprobability")

# %%
inds = np.sort(np.random.choice(range(len(df)), size=int(np.floor(len(df)/1000)), replace=False))
len(inds)
# Out:
# 256

# %%
for j in range(len(inds)):
    
#     if sys.argv[1] != "-f":
#         params_df = df.iloc[int(sys.argv[2])]
#     else:
#         params_df = df.iloc[0]
    
    params_df = df.iloc[inds[j]]
    
    Nplanets = 3
    params = radvel.Parameters(Nplanets, basis='per tc secosw sesinw k')
    for col in df.columns:
        params[col] = radvel.Parameter(value=params_df[col])
    new_params = params.basis.to_any_basis(params, 'per tp e w k')

    #set up simulation
    sim = rebound.Simulation()

    sim.collision = 'line'

    sim.collision_resolve = sf.collision

    #add star
    Mstar = 1.145
    sim.add(m=Mstar)

    incs = np.pi / 180 * np.array([sf.a_normal(85.5, 1.5, 0.5), sf.a_normal(86.23, 0.26, 0.26), sf.a_normal(87.43, 0.18, 0.19)])

    for i in range(3):
        P = float(new_params["per%d"%(i+1)]) / days_p_year
        e = float(new_params["e%d"%(i+1)]) # Omega = W  # longitude of ascending node 
        T = float(new_params["tp%d"%(i+1)])
        pomega = float(new_params["w%d"%(i+1)])  # longitude of periastron  
        inc = incs[i]
        m = sf.mass_from_VSA(P, Mstar, float(new_params["k%d"%(i+1)]), e, inc) * earth_mass_2_solar_mass

        # omega = w
        # M = M
        r = (1 - e) * np.cbrt(P * P * m * earth_mass_2_solar_mass / Mstar / 3) / 2

        # sim.add(m=m, P=P / year_p_reboundtime, e=e, inc=inc - np.pi/2, Omega=W, omega=w, M=M, r=radii[i]) #G=1 units!
        sim.add(m=m, P=P / year_p_reboundtime, e=e, inc=inc - np.pi/2, T=T, pomega=pomega, r=r) #G=1 units!

    sim.move_to_com()
    
    sf.stability_score(sim)  # dummy score
    
    # initialize list of lists 
    data = [[inds[j], sf.stability_score(sim)]] 

    if j==0:
        save_df = pd.DataFrame(data, columns = ['ind', 'score'])
    else:
        save_df = save_df.append(pd.DataFrame(data, columns = ['ind', 'score']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-98e4b4b5b1bf> in <module>
#      44     sim.move_to_com()
#      45
# ---> 46     sf.stability_score(sim)  # dummy score
#      47
#      48     # initialize list of lists
#
# /storage/work/c/cjg66/Dan_research/Stability-Priors/stability_functions.py in stability_score(sim)
#     113 def stability_score(sim):
#     114     args = (10000, 1000) # (Norbits, Nout) Keep this fixed
# --> 115     summaryfeatures = ressummaryfeaturesxgbv6(sim, args)
#     116     if features is not None:
#     117         summaryfeatures = summaryfeatures[features]
#
# /storage/work/c/cjg66/Dan_research/MLstability/generate_training_data/training_data_functions.py in ressummaryfeaturesxgbv6(sim, args)
#    1252     Npairs = int((N-1)*(N-2)/2)
#    1253
# -> 1254     features = resparamsv5(sim, args)
#    1255     pairs = getpairsv5(sim)
#    1256
#
# /storage/work/c/cjg66/Dan_research/MLstability/generate_training_data/training_data_functions.py in resparamsv5(sim, args)
#    1134         features['EMcross'+label] = (ps[int(i2)].a-ps[int(i1)].a)/ps[int(i1)].a
#    1135         features['j'+label], features['k'+label], features['strength'+label] = findresv3(sim, i1, i2) # returns -1s if no res found
# -> 1136         features["C_AMD"+label] = AMD_stability_coefficient(sim, i1, i2)
#    1137         features['reshalfwidth'+label] = np.nan # so we always populate in case there's no  separatrix
#    1138         if features['strength'+label] > 0:
#
# /storage/work/c/cjg66/Dan_research/MLstability/generate_training_data/training_data_functions.py in AMD_stability_coefficient(sim, i1, i2)
#     126     gamma = pIn.m / pOut.m
#     127     LmbdaOut = pOut.m * np.sqrt(orbOut.a)
# --> 128     Ccrit = critical_relative_AMD(alpha,gamma)
#     129     C = AMD / LmbdaOut
#     130     return C / Ccrit
#
# /storage/work/c/cjg66/Dan_research/MLstability/generate_training_data/training_data_functions.py in critical_relative_AMD(alpha, gamma)
#      56     """Equation 29"""
#      57     e0 = np.min((1,1/alpha-1))
# ---> 58     ec = brenth(F,0,e0,args=(alpha,gamma))
#      59     e1c = np.sin(np.arctan(gamma*ec / np.sqrt(alpha*(1-ec*ec))))
#      60     curlyC = gamma*np.sqrt(alpha) * (1-np.sqrt(1-ec*ec)) + (1 - np.sqrt(1-e1c*e1c))
#
# ~/miniconda3/lib/python3.7/site-packages/scipy/optimize/zeros.py in brenth(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     855     if rtol < _rtol:
#     856         raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 857     r = _zeros._brenth(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     858     return results_c(full_output, r)
#     859
#
# ValueError: f(a) and f(b) must have different signs

# %%
# save_df.to_pickle("stab_scores_%d.pkl"%err_ind)
err_ind = 4
pd.read_pickle("stab_scores_%d.pkl"%err_ind)
# Out:
#        ind     score
# 0     1270  0.980673
# 0     7848  0.985957
# 0     8024  0.980003
# 0     8064  0.954848
# 0     8329  0.996209
# 0    12302  0.981554
# 0    12331  0.997852
# 0    13415  0.997754
# 0    14467  0.996579
# 0    14764  0.992014
# 0    14765  0.941151
# 0    15894  0.996425
# 0    17411  0.977216
# 0    17797  0.995412
# 0    19401  0.993278
# 0    19460  0.997429
# 0    20621  0.996782
# 0    22805  0.982505
# 0    22876  0.997301
# 0    25015  0.970037
# 0    25117  0.992349
# 0    25219  0.972170
# 0    26115  0.972170
# 0    26702  0.996265
# 0    27630  0.977318
# 0    27777  0.967747
# 0    28700  0.996262
# 0    29121  0.997078
# 0    29509  0.983938
# 0    30631  0.997221
# ..     ...       ...
# 0   216437  0.999178
# 0   216588  0.990739
# 0   216797  0.999355
# 0   219851  0.992564
# 0   220080  0.998116
# 0   220465  0.991438
# 0   221527  0.998934
# 0   221762  0.964298
# 0   222693  0.951309
# 0   223740  0.998085
# 0   226470  0.984902
# 0   227684  0.995995
# 0   228323  0.998311
# 0   230846  0.900552
# 0   231549  0.998623
# 0   233415  0.996424
# 0   233941  0.996784
# 0   233970  0.998362
# 0   235228  0.996380
# 0   236810  0.998612
# 0   237601  0.995767
# 0   237725  0.971586
# 0   238043  0.987331
# 0   238797  0.971586
# 0   239233  0.980789
# 0   239588  0.997124
# 0   239902  0.973109
# 0   240959  0.996717
# 0   241186  0.977371
# 0   241504  0.999300
#
# [243 rows x 2 columns]
